# %%
from IPython.core.display import HTML
HTML("<style>.container { width:100% !important; }</style>")

# %%
# %matplotlib inline

# %%
# %run initialize_notebook.ipynb
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from helpers import eimod, lcahelp
eimod.init()
# Out:
# Geomatcher: Used 'AU' for 'AUS'
# Geomatcher: Used 'CA' for 'CAN'
# Geomatcher: Used 'HM' for 'HMD'
# Geomatcher: Used 'NZ' for 'NZL'
# Geomatcher: Used 'PM' for 'SPM'
# Geomatcher: Used 'CN' for 'CHN'
# Geomatcher: Used 'HK' for 'HKG'
# Geomatcher: Used 'MO' for 'MAC'
# Geomatcher: Used 'TW' for 'TWN'
# Geomatcher: Used 'AX' for 'ALA'
# Geomatcher: Used 'AT' for 'AUT'
# Geomatcher: Used 'BE' for 'BEL'
# Geomatcher: Used 'BG' for 'BGR'
# Geomatcher: Used 'CY' for 'CYP'
# Geomatcher: Used 'CZ' for 'CZE'
# Geomatcher: Used 'DE' for 'DEU'
# Geomatcher: Used 'DK' for 'DNK'
# Geomatcher: Used 'ES' for 'ESP'
# Geomatcher: Used 'EE' for 'EST'
# Geomatcher: Used 'FI' for 'FIN'
# Geomatcher: Used 'FR' for 'FRA'
# Geomatcher: Used 'FO' for 'FRO'
# Geomatcher: Used 'GB' for 'GBR'
# Geomatcher: Used 'GI' for 'GIB'
# Geomatcher: Used 'GR' for 'GRC'
# Geomatcher: Used 'HR' for 'HRV'
# Geomatcher: Used 'HU' for 'HUN'
# Geomatcher: Used 'IM' for 'IMN'
# Geomatcher: Used 'IE' for 'IRL'
# Geomatcher: Used 'IT' for 'ITA'
# Geomatcher: Used 'LT' for 'LTU'
# Geomatcher: Used 'LU' for 'LUX'
# Geomatcher: Used 'LV' for 'LVA'
# Geomatcher: Used 'MT' for 'MLT'
# Geomatcher: Used 'NL' for 'NLD'
# Geomatcher: Used 'PL' for 'POL'
# Geomatcher: Used 'PT' for 'PRT'
# Geomatcher: Used 'RO' for 'ROU'
# Geomatcher: Used 'SK' for 'SVK'
# Geomatcher: Used 'SI' for 'SVN'
# Geomatcher: Used 'SE' for 'SWE'
# Geomatcher: Used 'IN' for 'IND'
# Geomatcher: Used 'JP' for 'JPN'
# Geomatcher: Used 'AW' for 'ABW'
# Geomatcher: Used 'AI' for 'AIA'
# Geomatcher: Used 'AR' for 'ARG'
# Geomatcher: Used 'AQ' for 'ATA'
# Geomatcher: Used 'AG' for 'ATG'
# Geomatcher: Used 'BQ' for 'BES'
# Geomatcher: Used 'BS' for 'BHS'
# Geomatcher: Used 'BZ' for 'BLZ'
# Geomatcher: Used 'BM' for 'BMU'
# Geomatcher: Used 'BO' for 'BOL'
# Geomatcher: Used 'BR' for 'BRA'
# Geomatcher: Used 'BB' for 'BRB'
# Geomatcher: Used 'BV' for 'BVT'
# Geomatcher: Used 'CL' for 'CHL'
# Geomatcher: Used 'CO' for 'COL'
# Geomatcher: Used 'CR' for 'CRI'
# Geomatcher: Used 'CU' for 'CUB'
# Geomatcher: Used 'CW' for 'CUW'
# Geomatcher: Used 'KY' for 'CYM'
# Geomatcher: Used 'DM' for 'DMA'
# Geomatcher: Used 'DO' for 'DOM'
# Geomatcher: Used 'EC' for 'ECU'
# Geomatcher: Used 'FK' for 'FLK'
# Geomatcher: Used 'GP' for 'GLP'
# Geomatcher: Used 'GD' for 'GRD'
# Geomatcher: Used 'GT' for 'GTM'
# Geomatcher: Used 'GF' for 'GUF'
# Geomatcher: Used 'GY' for 'GUY'
# Geomatcher: Used 'HN' for 'HND'
# Geomatcher: Used 'HT' for 'HTI'
# Geomatcher: Used 'JM' for 'JAM'
# Geomatcher: Used 'KN' for 'KNA'
# Geomatcher: Used 'LC' for 'LCA'
# Geomatcher: Used 'MX' for 'MEX'
# Geomatcher: Used 'MS' for 'MSR'
# Geomatcher: Used 'MQ' for 'MTQ'
# Geomatcher: Used 'NI' for 'NIC'
# Geomatcher: Used 'PA' for 'PAN'
# Geomatcher: Used 'PE' for 'PER'
# Geomatcher: Used 'PR' for 'PRI'
# Geomatcher: Used 'PY' for 'PRY'
# Geomatcher: Used 'GS' for 'SGS'
# Geomatcher: Used 'SV' for 'SLV'
# Geomatcher: Used 'SR' for 'SUR'
# Geomatcher: Used 'SX' for 'SXM'
# Geomatcher: Used 'TC' for 'TCA'
# Geomatcher: Used 'TT' for 'TTO'
# Geomatcher: Used 'UY' for 'URY'
# Geomatcher: Used 'VC' for 'VCT'
# Geomatcher: Used 'VE' for 'VEN'
# Geomatcher: Used 'VG' for 'VGB'
# Geomatcher: Used 'VI' for 'VIR'
# Geomatcher: Used 'AE' for 'ARE'
# Geomatcher: Used 'BH' for 'BHR'
# Geomatcher: Used 'DZ' for 'DZA'
# Geomatcher: Used 'EG' for 'EGY'
# Geomatcher: Used 'EH' for 'ESH'
# Geomatcher: Used 'IR' for 'IRN'
# Geomatcher: Used 'IQ' for 'IRQ'
# Geomatcher: Used 'IL' for 'ISR'
# Geomatcher: Used 'JO' for 'JOR'
# Geomatcher: Used 'KW' for 'KWT'
# Geomatcher: Used 'LB' for 'LBN'
# Geomatcher: Used 'LY' for 'LBY'
# Geomatcher: Used 'MA' for 'MAR'
# Geomatcher: Used 'OM' for 'OMN'
# Geomatcher: Used 'PS' for 'PSE'
# Geomatcher: Used 'QA' for 'QAT'
# Geomatcher: Used 'SA' for 'SAU'
# Geomatcher: Used 'SD' for 'SDN'
# Geomatcher: Used 'SY' for 'SYR'
# Geomatcher: Used 'TN' for 'TUN'
# Geomatcher: Used 'YE' for 'YEM'
# Geomatcher: Used 'AL' for 'ALB'
# Geomatcher: Used 'AD' for 'AND'
# Geomatcher: Used 'BA' for 'BIH'
# Geomatcher: Used 'CH' for 'CHE'
# Geomatcher: Used 'GL' for 'GRL'
# Geomatcher: Used 'IS' for 'ISL'
# Geomatcher: Used 'LI' for 'LIE'
# Geomatcher: Used 'MC' for 'MCO'
# Geomatcher: Used 'MK' for 'MKD'
# Geomatcher: Used 'ME' for 'MNE'
# Geomatcher: Used 'NO' for 'NOR'
# Geomatcher: Used 'SJ' for 'SJM'
# Geomatcher: Used 'SM' for 'SMR'
# Geomatcher: Used 'RS' for 'SRB'
# Geomatcher: Used 'TR' for 'TUR'
# Geomatcher: Used 'VA' for 'VAT'
# Geomatcher: Used 'AF' for 'AFG'
# Geomatcher: Used 'AS' for 'ASM'
# Geomatcher: Used 'TF' for 'ATF'
# Geomatcher: Used 'BD' for 'BGD'
# Geomatcher: Used 'BN' for 'BRN'
# Geomatcher: Used 'BT' for 'BTN'
# Geomatcher: Used 'CK' for 'COK'
# Geomatcher: Used 'FJ' for 'FJI'
# Geomatcher: Used 'FM' for 'FSM'
# Geomatcher: Used 'GU' for 'GUM'
# Geomatcher: Used 'ID' for 'IDN'
# Geomatcher: Used 'IO' for 'IOT'
# Geomatcher: Used 'KH' for 'KHM'
# Geomatcher: Used 'KI' for 'KIR'
# Geomatcher: Used 'KR' for 'KOR'
# Geomatcher: Used 'LA' for 'LAO'
# Geomatcher: Used 'LK' for 'LKA'
# Geomatcher: Used 'MV' for 'MDV'
# Geomatcher: Used 'MH' for 'MHL'
# Geomatcher: Used 'MM' for 'MMR'
# Geomatcher: Used 'MN' for 'MNG'
# Geomatcher: Used 'MP' for 'MNP'
# Geomatcher: Used 'MY' for 'MYS'
# Geomatcher: Used 'NC' for 'NCL'
# Geomatcher: Used 'NF' for 'NFK'
# Geomatcher: Used 'NU' for 'NIU'
# Geomatcher: Used 'NP' for 'NPL'
# Geomatcher: Used 'NR' for 'NRU'
# Geomatcher: Used 'PK' for 'PAK'
# Geomatcher: Used 'PN' for 'PCN'
# Geomatcher: Used 'PH' for 'PHL'
# Geomatcher: Used 'PW' for 'PLW'
# Geomatcher: Used 'PG' for 'PNG'
# Geomatcher: Used 'KP' for 'PRK'
# Geomatcher: Used 'PF' for 'PYF'
# Geomatcher: Used 'SG' for 'SGP'
# Geomatcher: Used 'SB' for 'SLB'
# Geomatcher: Used 'TH' for 'THA'
# Geomatcher: Used 'TK' for 'TKL'
# Geomatcher: Used 'TL' for 'TLS'
# Geomatcher: Used 'TO' for 'TON'
# Geomatcher: Used 'TV' for 'TUV'
# Geomatcher: Used 'UM' for 'UMI'
# Geomatcher: Used 'VN' for 'VNM'
# Geomatcher: Used 'VU' for 'VUT'
# Geomatcher: Used 'WF' for 'WLF'
# Geomatcher: Used 'WS' for 'WSM'
# Geomatcher: Used 'AM' for 'ARM'
# Geomatcher: Used 'AZ' for 'AZE'
# Geomatcher: Used 'BY' for 'BLR'
# Geomatcher: Used 'GE' for 'GEO'
# Geomatcher: Used 'KZ' for 'KAZ'
# Geomatcher: Used 'KG' for 'KGZ'
# Geomatcher: Used 'MD' for 'MDA'
# Geomatcher: Used 'RU' for 'RUS'
# Geomatcher: Used 'TJ' for 'TJK'
# Geomatcher: Used 'TM' for 'TKM'
# Geomatcher: Used 'UA' for 'UKR'
# Geomatcher: Used 'UZ' for 'UZB'
# Geomatcher: Used 'AO' for 'AGO'
# Geomatcher: Used 'BI' for 'BDI'
# Geomatcher: Used 'BJ' for 'BEN'
# Geomatcher: Used 'BF' for 'BFA'
# Geomatcher: Used 'BW' for 'BWA'
# Geomatcher: Used 'CF' for 'CAF'
# Geomatcher: Used 'CI' for 'CIV'
# Geomatcher: Used 'CM' for 'CMR'
# Geomatcher: Used 'CD' for 'COD'
# Geomatcher: Used 'CG' for 'COG'
# Geomatcher: Used 'KM' for 'COM'
# Geomatcher: Used 'CV' for 'CPV'
# Geomatcher: Used 'DJ' for 'DJI'
# Geomatcher: Used 'ER' for 'ERI'
# Geomatcher: Used 'ET' for 'ETH'
# Geomatcher: Used 'GA' for 'GAB'
# Geomatcher: Used 'GH' for 'GHA'
# Geomatcher: Used 'GN' for 'GIN'
# Geomatcher: Used 'GM' for 'GMB'
# Geomatcher: Used 'GW' for 'GNB'
# Geomatcher: Used 'GQ' for 'GNQ'
# Geomatcher: Used 'KE' for 'KEN'
# Geomatcher: Used 'LR' for 'LBR'
# Geomatcher: Used 'LS' for 'LSO'
# Geomatcher: Used 'MG' for 'MDG'
# Geomatcher: Used 'ML' for 'MLI'
# Geomatcher: Used 'MZ' for 'MOZ'
# Geomatcher: Used 'MR' for 'MRT'
# Geomatcher: Used 'MU' for 'MUS'
# Geomatcher: Used 'MW' for 'MWI'
# Geomatcher: Used 'YT' for 'MYT'
# Geomatcher: Used 'NA' for 'NAM'
# Geomatcher: Used 'NE' for 'NER'
# Geomatcher: Used 'NG' for 'NGA'
# Geomatcher: Used 'RE' for 'REU'
# Geomatcher: Used 'RW' for 'RWA'
# Geomatcher: Used 'SN' for 'SEN'
# Geomatcher: Used 'SH' for 'SHN'
# Geomatcher: Used 'SL' for 'SLE'
# Geomatcher: Used 'SO' for 'SOM'
# Geomatcher: Used 'SS' for 'SSD'
# Geomatcher: Used 'ST' for 'STP'
# Geomatcher: Used 'SZ' for 'SWZ'
# Geomatcher: Used 'SC' for 'SYC'
# Geomatcher: Used 'TD' for 'TCD'
# Geomatcher: Used 'TG' for 'TGO'
# Geomatcher: Used 'TZ' for 'TZA'
# Geomatcher: Used 'UG' for 'UGA'
# Geomatcher: Used 'ZA' for 'ZAF'
# Geomatcher: Used 'ZM' for 'ZMB'
# Geomatcher: Used 'ZW' for 'ZWE'
# Geomatcher: Used 'US' for 'USA'

# %%
from wurst import searching as ws
from wurst.ecoinvent import filters

# %%
databases
# Out:
# Databases dictionary with 21 objects, including:
# 	Carma CCS
# 	biosphere3
# 	coal_exit_INDC_2020
# 	coal_exit_INDC_2030
# 	coal_exit_INDC_2040
# 	coal_exit_INDC_2050
# 	coal_exit_RCP26_2020
# 	coal_exit_RCP26_2030
# 	coal_exit_RCP26_2040
# 	coal_exit_RCP26_2050
# Use `list(this object)` to get the complete list.

# %%
database_dict = {}
database_dict['ecoinvent_added_technologies'] = {'year' : 2015 , 'scenario' : 'ecoinvent'}

for year in [2015, 2030, 2050]:
    for scenario in ['Ref', 'INDC', 'coal_exit', 'RCP26']:
        if year == 2015 and scenario != 'Ref':
            continue
        db_name = 'coal_exit_' + scenario + '_' + str(year)
        database_dict[db_name] = {'year' : year , 'scenario' : scenario}

# %%
database_dict
# Out:
# {'ecoinvent_added_technologies': {'year': 2015, 'scenario': 'ecoinvent'},
#  'coal_exit_Ref_2015': {'year': 2015, 'scenario': 'Ref'},
#  'coal_exit_Ref_2030': {'year': 2030, 'scenario': 'Ref'},
#  'coal_exit_INDC_2030': {'year': 2030, 'scenario': 'INDC'},
#  'coal_exit_coal_exit_2030': {'year': 2030, 'scenario': 'coal_exit'},
#  'coal_exit_RCP26_2030': {'year': 2030, 'scenario': 'RCP26'},
#  'coal_exit_Ref_2050': {'year': 2050, 'scenario': 'Ref'},
#  'coal_exit_INDC_2050': {'year': 2050, 'scenario': 'INDC'},
#  'coal_exit_coal_exit_2050': {'year': 2050, 'scenario': 'coal_exit'},
#  'coal_exit_RCP26_2050': {'year': 2050, 'scenario': 'RCP26'}}

# %%
db_order = ['ecoinvent_added_technologies',
            'coal_exit_Ref_2015',

            'coal_exit_Ref_2030',
            'coal_exit_INDC_2030',
            'coal_exit_coal_exit_2030',
            'coal_exit_RCP26_2030',

            'coal_exit_Ref_2050',
            'coal_exit_INDC_2050',
            'coal_exit_coal_exit_2050',
            'coal_exit_RCP26_2050'
            ]

# %%
db_tuples = []
for db in db_order:  
    db_tuples.append((database_dict[db]['year'], database_dict[db]['scenario']))

# %% [markdown]
# Let's create a dictionary of all remind and ecoinvent locations:

# %%
location_dict = {}
for ds in Database('coal_exit_Ref_2015'):
    if ds['location'] not in location_dict.keys():
        location_dict[ds['location']] = (eimod.ecoinvent_to_remind_locations(ds['location'], fixnames=False), ds['location'])

# %%
location_dict
# Out:
# {'RoW': (['OAS',
#    'LAM',
#    'EUR',
#    'CAZ',
#    'USA',
#    'NEU',
#    'MEA',
#    'REF',
#    'JPN',
#    'CHA',
#    'SSA',
#    'IND'],
#   'RoW'),
#  'GLO': (['OAS',
#    'LAM',
#    'EUR',
#    'CAZ',
#    'USA',
#    'NEU',
#    'MEA',
#    'REF',
#    'JPN',
#    'CHA',
#    'SSA',
#    'IND'],
#   'GLO'),
#  'RER': (['EUR', 'NEU', 'REF', 'LAM'], 'RER'),
#  'RME': (['MEA'], 'RME'),
#  'MT': (['EUR'], 'MT'),
#  'ME': (['NEU'], 'ME'),
#  'SE': (['EUR'], 'SE'),
#  'PE': (['LAM'], 'PE'),
#  'SD': (['MEA'], 'SD'),
#  'RO': (['EUR'], 'RO'),
#  'CH': (['NEU'], 'CH'),
#  'ZA': (['SSA'], 'ZA'),
#  'CA-MB': (['CAZ'], 'CA-MB'),
#  'Europe without Switzerland': (['EUR', 'NEU', 'REF', 'LAM'],
#   'Europe without Switzerland'),
#  'CA-NT': (['CAZ'], 'CA-NT'),
#  'PT': (['EUR'], 'PT'),
#  'HT': (['LAM'], 'HT'),
#  'EE': (['EUR'], 'EE'),
#  'CA-QC': (['CAZ'], 'CA-QC'),
#  'IN-North-eastern grid': (['IND'], 'IN-North-eastern grid'),
#  'US-ASCC': (['USA'], 'US-ASCC'),
#  'IN-MH': (['IND'], 'IN-MH'),
#  'HU': (['EUR'], 'HU'),
#  'SK': (['EUR'], 'SK'),
#  'MK': (['NEU'], 'MK'),
#  'PH': (['OAS'], 'PH'),
#  'US-RFC': (['USA'], 'US-RFC'),
#  'IS': (['NEU'], 'IS'),
#  'HR': (['EUR'], 'HR'),
#  'CA-ON': (['CAZ'], 'CA-ON'),
#  'DE': (['EUR'], 'DE'),
#  'TR': (['NEU'], 'TR'),
#  'CN-GD': (['CHA'], 'CN-GD'),
#  'CN-HU': (['CHA'], 'CN-HU'),
#  'BE': (['EUR'], 'BE'),
#  'CN-HB': (['CHA'], 'CN-HB'),
#  'IAI Area, EU27 & EFTA': (['EUR', 'NEU', 'LAM'], 'IAI Area, EU27 & EFTA'),
#  'RU': (['REF'], 'RU'),
#  'VN': (['OAS'], 'VN'),
#  'LB': (['MEA'], 'LB'),
#  'AT': (['EUR'], 'AT'),
#  'IN': (['IND'], 'IN'),
#  'FR': (['EUR'], 'FR'),
#  'US-HICC': (['USA'], 'US-HICC'),
#  'IT': (['EUR'], 'IT'),
#  'Canada without Quebec': (['CAZ'], 'Canada without Quebec'),
#  'CN': (['CHA'], 'CN'),
#  'SI': (['EUR'], 'SI'),
#  'CN-JL': (['CHA'], 'CN-JL'),
#  'CN-GZ': (['CHA'], 'CN-GZ'),
#  'US-TRE': (['USA'], 'US-TRE'),
#  'BG': (['EUR'], 'BG'),
#  'TH': (['OAS'], 'TH'),
#  'NO': (['NEU', 'LAM'], 'NO'),
#  'PL': (['EUR'], 'PL'),
#  'CN-GS': (['CHA'], 'CN-GS'),
#  'ES': (['EUR'], 'ES'),
#  'US-MRO': (['USA'], 'US-MRO'),
#  'CL': (['LAM'], 'CL'),
#  'US': (['USA'], 'US'),
#  'BR': (['LAM'], 'BR'),
#  'MY': (['OAS'], 'MY'),
#  'LU': (['EUR'], 'LU'),
#  'CA-NF': (['CAZ'], 'CA-NF'),
#  'AU': (['CAZ'], 'AU'),
#  'CN-HE': (['CHA'], 'CN-HE'),
#  'CI': (['SSA'], 'CI'),
#  'CN-HL': (['CHA'], 'CN-HL'),
#  'CN-ZJ': (['CHA'], 'CN-ZJ'),
#  'US-FRCC': (['USA'], 'US-FRCC'),
#  'CZ': (['EUR'], 'CZ'),
#  'IN-BR': (['IND'], 'IN-BR'),
#  'UCTE without Germany': (['EUR', 'NEU'], 'UCTE without Germany'),
#  'NORDEL': (['EUR', 'NEU', 'LAM'], 'NORDEL'),
#  'BA': (['NEU'], 'BA'),
#  'KP': (['OAS'], 'KP'),
#  'CN-LN': (['CHA'], 'CN-LN'),
#  'DZ': (['MEA'], 'DZ'),
#  'CA-PE': (['CAZ'], 'CA-PE'),
#  'YE': (['MEA'], 'YE'),
#  'CN-CQ': (['CHA'], 'CN-CQ'),
#  'DO': (['LAM'], 'DO'),
#  'EC': (['LAM'], 'EC'),
#  'TN': (['MEA'], 'TN'),
#  'IN-GA': (['IND'], 'IN-GA'),
#  'XK': (['EUR'], 'XK'),
#  'CN-SH': (['CHA'], 'CN-SH'),
#  'US-SERC': (['USA'], 'US-SERC'),
#  'US-WECC': (['USA'], 'US-WECC'),
#  'CD': (['SSA'], 'CD'),
#  'RNA': (['CAZ', 'USA', 'NEU', 'LAM'], 'RNA'),
#  'CN-QH': (['CHA'], 'CN-QH'),
#  'CY': (['EUR'], 'CY'),
#  'NL': (['EUR'], 'NL'),
#  'GR': (['EUR'], 'GR'),
#  'NP': (['OAS'], 'NP'),
#  'KR': (['OAS'], 'KR'),
#  'IAI Area, Russia & RER w/o EU27 & EFTA': (['REF'],
#   'IAI Area, Russia & RER w/o EU27 & EFTA'),
#  'AR': (['LAM'], 'AR'),
#  'KE': (['SSA'], 'KE'),
#  'GB': (['EUR'], 'GB'),
#  'TM': (['REF'], 'TM'),
#  'NZ': (['CAZ', 'OAS'], 'NZ'),
#  'UN-OCEANIA': (['OAS', 'CAZ'], 'UN-OCEANIA'),
#  'BW': (['SSA'], 'BW'),
#  'LT': (['EUR'], 'LT'),
#  'IAI Area, South America': (['LAM'], 'IAI Area, South America'),
#  'CA-AB': (['CAZ'], 'CA-AB'),
#  'CN-GX': (['CHA'], 'CN-GX'),
#  'LY': (['MEA'], 'LY'),
#  'HN': (['LAM'], 'HN'),
#  'IAI Area, Africa': (['MEA', 'SSA'], 'IAI Area, Africa'),
#  'RS': (['NEU'], 'RS'),
#  'IN-Western grid': (['IND'], 'IN-Western grid'),
#  'US-SPP': (['USA'], 'US-SPP'),
#  'CA-NB': (['CAZ'], 'CA-NB'),
#  'SV': (['LAM'], 'SV'),
#  'MN': (['OAS'], 'MN'),
#  'CN-NM': (['CHA'], 'CN-NM'),
#  'IN-Southern grid': (['IND'], 'IN-Southern grid'),
#  'AL': (['NEU'], 'AL'),
#  'RLA': (['LAM'], 'RLA'),
#  'CA': (['CAZ'], 'CA'),
#  'CN-AH': (['CHA'], 'CN-AH'),
#  'DK': (['EUR'], 'DK'),
#  'TZ': (['SSA'], 'TZ'),
#  'IR': (['MEA'], 'IR'),
#  'TW': (['CHA'], 'TW'),
#  'IAI Area, Gulf Cooperation Council': (['MEA'],
#   'IAI Area, Gulf Cooperation Council'),
#  'CN-FJ': (['CHA'], 'CN-FJ'),
#  'IN-TN': (['IND'], 'IN-TN'),
#  'IN-KA': (['IND'], 'IN-KA'),
#  'IL': (['MEA'], 'IL'),
#  'CG': (['SSA'], 'CG'),
#  'CR': (['LAM'], 'CR'),
#  'SA': (['MEA'], 'SA'),
#  'UA': (['REF'], 'UA'),
#  'CN-HN': (['CHA'], 'CN-HN'),
#  'CA-NS': (['CAZ'], 'CA-NS'),
#  'ZM': (['SSA'], 'ZM'),
#  'TJ': (['REF'], 'TJ'),
#  'CN-SA': (['CHA'], 'CN-SA'),
#  'BH': (['MEA'], 'BH'),
#  'CN-BJ': (['CHA'], 'CN-BJ'),
#  'IN-UP': (['IND'], 'IN-UP'),
#  'VE': (['LAM'], 'VE'),
#  'ID': (['OAS'], 'ID'),
#  'CN-SX': (['CHA'], 'CN-SX'),
#  'HK': (['CHA'], 'HK'),
#  'LV': (['EUR'], 'LV'),
#  'IE': (['EUR'], 'IE'),
#  'UY': (['LAM'], 'UY'),
#  'KH': (['OAS'], 'KH'),
#  'IN-PY': (['IND'], 'IN-PY'),
#  'MX': (['LAM'], 'MX'),
#  'IN-GJ': (['IND'], 'IN-GJ'),
#  'CN-SD': (['CHA'], 'CN-SD'),
#  'CN-JX': (['CHA'], 'CN-JX'),
#  'PG': (['OAS'], 'PG'),
#  'AO': (['SSA'], 'AO'),
#  'CA-YK': (['CAZ'], 'CA-YK'),
#  'CN-YN': (['CHA'], 'CN-YN'),
#  'US-NPCC': (['USA'], 'US-NPCC'),
#  'MA': (['MEA'], 'MA'),
#  'JM': (['LAM'], 'JM'),
#  'QA': (['MEA'], 'QA'),
#  'CN-TJ': (['CHA'], 'CN-TJ'),
#  'CA-SK': (['CAZ'], 'CA-SK'),
#  'FI': (['EUR'], 'FI'),
#  'KG': (['REF'], 'KG'),
#  'CA-BC': (['CAZ'], 'CA-BC'),
#  'IQ': (['MEA'], 'IQ'),
#  'NI': (['LAM'], 'NI'),
#  'IN-AP': (['IND'], 'IN-AP'),
#  'IN-WB': (['IND'], 'IN-WB'),
#  'BY': (['REF'], 'BY'),
#  'CW': (['LAM'], 'CW'),
#  'CA-NU': (['CAZ'], 'CA-NU'),
#  'IAI Area, Asia, without China and GCC': (['OAS',
#    'JPN',
#    'IND',
#    'NEU',
#    'REF',
#    'MEA'],
#   'IAI Area, Asia, without China and GCC'),
#  'CN-JS': (['CHA'], 'CN-JS'),
#  'IN-HR': (['IND'], 'IN-HR'),
#  'KW': (['MEA'], 'KW'),
#  'KZ': (['REF'], 'KZ'),
#  'JP': (['JPN'], 'JP'),
#  'BD': (['OAS'], 'BD'),
#  'MU': (['SSA'], 'MU'),
#  'AE': (['MEA'], 'AE'),
#  'ER': (['SSA'], 'ER'),
#  'GH': (['SSA'], 'GH'),
#  'CN-XJ': (['CHA'], 'CN-XJ'),
#  'MD': (['REF'], 'MD'),
#  'OM': (['MEA'], 'OM'),
#  'BN': (['OAS'], 'BN'),
#  'AZ': (['REF'], 'AZ'),
#  'NE': (['SSA'], 'NE'),
#  'PY': (['LAM'], 'PY'),
#  'RAS': (['OAS', 'MEA', 'JPN', 'CHA', 'REF', 'IND', 'NEU', 'EUR'], 'RAS'),
#  'CN-CSG': (['CHA'], 'CN-CSG'),
#  'LK': (['OAS'], 'LK'),
#  'ET': (['SSA'], 'ET'),
#  'IN-Eastern grid': (['IND'], 'IN-Eastern grid'),
#  'TT': (['LAM'], 'TT'),
#  'SY': (['MEA'], 'SY'),
#  'IN-RJ': (['IND'], 'IN-RJ'),
#  'GA': (['SSA'], 'GA'),
#  'CU': (['LAM'], 'CU'),
#  'CM': (['SSA'], 'CM'),
#  'NG': (['SSA'], 'NG'),
#  'PA': (['LAM'], 'PA'),
#  'UZ': (['REF'], 'UZ'),
#  'IN-KL': (['IND'], 'IN-KL'),
#  'RAF': (['SSA', 'MEA'], 'RAF'),
#  'CN-NX': (['CHA'], 'CN-NX'),
#  'CO': (['LAM'], 'CO'),
#  'CN-SC': (['CHA'], 'CN-SC'),
#  'IN-PB': (['IND'], 'IN-PB'),
#  'MM': (['OAS'], 'MM'),
#  'IN-UT': (['IND'], 'IN-UT'),
#  'ZW': (['SSA'], 'ZW'),
#  'IN-DL': (['IND'], 'IN-DL'),
#  'AM': (['REF'], 'AM'),
#  'IN-CT': (['IND'], 'IN-CT'),
#  'CN-XZ': (['CHA'], 'CN-XZ'),
#  'CN-HA': (['CHA'], 'CN-HA'),
#  'IN-JH': (['IND'], 'IN-JH'),
#  'IN-HP': (['IND'], 'IN-HP'),
#  'IN-AS': (['IND'], 'IN-AS'),
#  'CN-SGCC': (['CHA'], 'CN-SGCC'),
#  'SS': (['SSA'], 'SS'),
#  'PK': (['OAS'], 'PK'),
#  'IN-Northern grid': (['IND'], 'IN-Northern grid'),
#  'GT': (['LAM'], 'GT'),
#  'IN-NL': (['IND'], 'IN-NL'),
#  'IN-TR': (['IND'], 'IN-TR'),
#  'SN': (['SSA'], 'SN'),
#  'GI': (['EUR'], 'GI'),
#  'BO': (['LAM'], 'BO'),
#  'Europe, without Russia and Turkey': (['EUR', 'NEU', 'REF', 'LAM'],
#   'Europe, without Russia and Turkey'),
#  'UCTE': (['EUR', 'NEU'], 'UCTE'),
#  'NA': (['SSA'], 'NA'),
#  'IN-MN': (['IND'], 'IN-MN'),
#  'ENTSO-E': (['EUR', 'NEU', 'LAM'], 'ENTSO-E'),
#  'GE': (['REF'], 'GE'),
#  'MG': (['SSA'], 'MG'),
#  'RER w/o CH+DE': (['EUR', 'NEU', 'REF', 'LAM'], 'RER w/o CH+DE'),
#  'MZ': (['SSA'], 'MZ'),
#  'IN-MP': (['IND'], 'IN-MP'),
#  'EG': (['MEA'], 'EG'),
#  'TG': (['SSA'], 'TG'),
#  'BJ': (['SSA'], 'BJ'),
#  'IN-AR': (['IND'], 'IN-AR'),
#  'CENTREL': (['EUR'], 'CENTREL'),
#  'IN-ML': (['IND'], 'IN-ML'),
#  'IN-OR': (['IND'], 'IN-OR'),
#  'IN-JK': (['IND'], 'IN-JK'),
#  'RER w/o DE+NL+RU': (['EUR', 'NEU', 'REF', 'LAM'], 'RER w/o DE+NL+RU'),
#  'JO': (['MEA'], 'JO'),
#  'SG': (['OAS'], 'SG'),
#  'IN-SK': (['IND'], 'IN-SK'),
#  'WEU': (['EUR', 'NEU'], 'WEU'),
#  'WECC': (['CAZ', 'USA'], 'WECC')}

# %% [markdown]
# # Electricity markets

# %%
electricity_markets = {}
electricity_markets_LCIA= {}

for db_name in database_dict:

    electricity_markets[db_name] = [x for x in ws.get_many(Database(db_name), *[*eimod.electricity_market_filter_high_voltage, ws.exclude(ws.contains('name', 'Swiss Federal Railways')),
                                                                                ws.exclude(ws.contains('name', 'label-certified'))])]

    electricity_markets_LCIA[(database_dict[db_name]['year'], database_dict[db_name]['scenario'])] = lcahelp.LCA_to_df(electricity_markets[db_name], cats = ['CC'])
# Out:
# CC
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:03
# CC
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:02
# CC
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:02
# CC
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:02
# CC
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:02
# CC
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:02
# CC
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:03
# CC
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:03
# CC
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:02
# CC
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:03
# CC
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:02
# CC
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:02
# CC
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:03
# CC
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:03
# CC
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:03
# CC
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:02
# CC
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:02
# CC
# 0% [##############################] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:02

# %%
pd \
    .concat(electricity_markets_LCIA)['CC'] \
        .unstack(level = [0,1]) \
        .rename(index=lambda el: el[1]) \
        .sort_values(by = (2015, 'BAU')) \
    .head(90)[db_tuples] \
    .plot.bar(figsize = (30,6), title = lcahelp.titles['CC'] + " Best 90 Countries")

# %%
pd \
    .concat(electricity_markets_LCIA)['CC'] \
        .unstack(level = [0,1]) \
        .rename(index=lambda el: el[1]) \
        .sort_values(by = (2015, 'BAU')) \
    .tail(90)[db_tuples] \
    .plot.bar(figsize = (30,6), title = lcahelp.titles['CC'] + " Worst 90 Countries")

# %% [markdown]
# We see consistency in the REMIND results for different regions, but the ecoinvent results are quite different than the REMIND 2015 numbers. This is due mostly to the different regional splits - ie Switerland and Norway are given "dirty" European average electricity.

# %% [markdown]
# Let's do the same, but group by remind location:

# %%
pd \
    .concat(electricity_markets_LCIA)['CC'] \
    .unstack(level = [0,1]) \
    .rename(index=lambda el: el[1]) \
    .sort_index() \
    .head(90)[db_tuples] \
    .plot.bar(figsize = (30,6), title = lcahelp.titles['CC'] + " First 90 Countries")

# %%
pd \
    .concat(electricity_markets_LCIA)['CC'] \
    .unstack(level = [0,1]) \
    .rename(index=lambda el: el[1]) \
    .sort_index() \
    .tail(90)[db_tuples] \
    .plot.bar(figsize = (30,6), title = lcahelp.titles['CC'] + " Second 90 Countries")

# %% [markdown]
# The Remind modified results seem to be quite similar for different remind regions - which is what we would expect.

# %% [markdown]
# # market groups

# %%
[act for act in Database("coal_exit_Ref_2015") if act["name"].startswith("market group for electricity, high voltage")]
# Out:
# ['market group for electricity, high voltage' (kilowatt hour, RNA, None),
#  'market group for electricity, high voltage' (kilowatt hour, Canada without Quebec, None),
#  'market group for electricity, high voltage' (kilowatt hour, RME, None),
#  'market group for electricity, high voltage' (kilowatt hour, CN, None),
#  'market group for electricity, high voltage' (kilowatt hour, RAF, None),
#  'market group for electricity, high voltage' (kilowatt hour, Europe without Switzerland, None),
#  'market group for electricity, high voltage' (kilowatt hour, UCTE, None),
#  'market group for electricity, high voltage' (kilowatt hour, RLA, None),
#  'market group for electricity, high voltage' (kilowatt hour, ENTSO-E, None),
#  'market group for electricity, high voltage' (kilowatt hour, RER, None),
#  'market group for electricity, high voltage' (kilowatt hour, IN, None),
#  'market group for electricity, high voltage' (kilowatt hour, GLO, None),
#  'market group for electricity, high voltage' (kilowatt hour, RAS, None),
#  'market group for electricity, high voltage' (kilowatt hour, CA, None),
#  'market group for electricity, high voltage' (kilowatt hour, US, None)]

# %%
electricity_market_groups = {}
electricity_market_groups_LCIA= {}

for db_name in database_dict:
    electricity_market_groups[db_name] = [
        x for x in ws.get_many(Database(db_name), 
                               *[equals('name', 'market group for electricity, high voltage')])]
    electricity_market_groups_LCIA[(database_dict[db_name]['year'], 
                                    database_dict[db_name]['scenario'])] = lcahelp.LCA_to_df(
        electricity_market_groups[db_name], cats = ['CC', 'R_Total', 'PMF'])
# Out:
# CC
# 0% [###############] 100% | ETA: 00:00:00
# R_Total
# Total time elapsed: 00:00:00
# 0% [###############] 100% | ETA: 00:00:00
# PMF
# Total time elapsed: 00:00:00
# 0% [###############] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# CC
# 0% [###############] 100% | ETA: 00:00:00
# R_Total
# Total time elapsed: 00:00:00
# 0% [###############] 100% | ETA: 00:00:00
# PMF
# Total time elapsed: 00:00:00
# 0% [###############] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# CC
# 0% [###############] 100% | ETA: 00:00:00
# R_Total
# Total time elapsed: 00:00:00
# 0% [###############] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# PMF
# 0% [###############] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# CC
# 0% [###############] 100% | ETA: 00:00:00
# R_Total
# Total time elapsed: 00:00:00
# 0% [###############] 100% | ETA: 00:00:00
# PMF
# Total time elapsed: 00:00:00
# 0% [###############] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# CC
# 0% [###############] 100% | ETA: 00:00:00
# R_Total
# Total time elapsed: 00:00:00
# 0% [###############] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# PMF
# 0% [###############] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# CC
# 0% [###############] 100% | ETA: 00:00:00
# R_Total
# Total time elapsed: 00:00:00
# 0% [###############] 100% | ETA: 00:00:00
# PMF
# Total time elapsed: 00:00:00
# 0% [###############] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# CC
# 0% [###############] 100% | ETA: 00:00:00
# R_Total
# Total time elapsed: 00:00:00
# 0% [###############] 100% | ETA: 00:00:00
# PMF
# Total time elapsed: 00:00:00
# 0% [###############] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# CC
# 0% [###############] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# R_Total
# 0% [###############] 100% | ETA: 00:00:00
# PMF
# Total time elapsed: 00:00:00
# 0% [###############] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# CC
# 0% [###############] 100% | ETA: 00:00:00
# R_Total
# Total time elapsed: 00:00:00
# 0% [###############] 100% | ETA: 00:00:00
# PMF
# Total time elapsed: 00:00:00
# 0% [###############] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00
# CC
# 0% [###############] 100% | ETA: 00:00:00
# R_Total
# Total time elapsed: 00:00:00
# 0% [###############] 100% | ETA: 00:00:00
# PMF
# Total time elapsed: 00:00:00
# 0% [###############] 100% | ETA: 00:00:00
# Total time elapsed: 00:00:00

# %%
for cat in ['CC', 'PMF', 'R_Total']:
    ax = pd \
        .concat(electricity_market_groups_LCIA)[cat] \
        .unstack(level = [0,1]) \
        .rename(index=lambda el: el[1]) \
        .sort_values(by = (2015, 'Ref')) \
        .plot.bar(figsize = (30,6), title = lcahelp.titles[cat])
    ax.set_ylabel(lcahelp.units[cat] + "/kWh")

# %% [markdown]
# #  Coal:

# %%
coal_datasets = {}
coal_LCIA= {}

for db_name in database_dict:

    coal_datasets[db_name] = [x for x in get_many(Database(db_name), *filters.coal_electricity)]
    lca = LCA({coal_datasets[db_name][0]: 1}, method=lcia_methods['CC'])
    lca.lci()
    lca.lcia()
    lca.score
    coal_LCIA[(database_dict[db_name]['year'], database_dict[db_name]['scenario'])] = LCA_to_df(coal_datasets[db_name], cats = ['CC', 'PMF', 'POF', 'R_Total'])

# %%
for cat in coal_LCIA[(2015,'BAU')].columns:
    ax = pd.concat(coal_LCIA)[cat].unstack(level = [0,1]).loc['electricity production, hard coal'].sort_values(by = (2015, 'BAU')).rename(index = location_dict)[db_tuples].plot.bar(figsize = (30,6), title = titles[cat])
    ax.set_ylabel(units[cat] + "/kWh")

# %%
for cat in coal_LCIA[(2015,'BAU')].columns:
    ax = pd.concat(coal_LCIA)[cat].unstack(level = [0,1]).loc['electricity production, lignite'].sort_values(by = (2015, 'BAU')).rename(index = location_dict)[db_tuples].plot.bar(figsize = (30,6), title = titles[cat])
    ax.set_ylabel(units[cat] + "/kWh")

# %% [markdown]
# Okay, PMF and POF are getting way better, but we didn't change the PM emissions using the remind data (only scaled by efficiency). What's causing the PMF and POF impacts in hard coal electricity?

# %%
coal_contribution_LCIA = {}

for db_name in database_dict:

    lca = LCA({coal_datasets[db_name][0]: 1}, method=lcia_methods['CC'])
    lca.lci()
    lca.lcia()
    lca.score
    coal_contribution_LCIA[(database_dict[db_name]['year'], database_dict[db_name]['scenario'])] = contribution_LCA_to_df(coal_datasets[db_name], cats = ['CC', 'PMF', 'POF', 'R_Total'])

# %%
for cat in ['PMF', 'POF']:
    for db_name in database_dict:
        ax = group_into_other(coal_contribution_LCIA[(database_dict[db_name]['year'], database_dict[db_name]['scenario'])].loc['electricity production, hard coal'].dropna(
            how = 'all', axis=1)).rename(index = location_dict)[cat].sort_index().plot.bar(stacked=True,figsize = (30,6), title = db_name + " " + titles[cat])
        ax.set_ylabel(units[cat] + "/kWh")

# %%
for cat in ['PMF', 'POF']:
    for db_name in database_dict:
        ax = group_into_other(coal_contribution_LCIA[(database_dict[db_name]['year'], database_dict[db_name]['scenario'])].loc['electricity production, lignite'].dropna(
            how = 'all', axis=1)).rename(index = location_dict)[cat].sort_index().plot.bar(stacked=True,figsize = (30,6), title = db_name + " " + titles[cat])
        ax.set_ylabel(units[cat] + "/kWh")

# %% [markdown]
# We see that not modifying the PM emissions is definitely not a good solution. We should find a way to include this! Everything else seems to make sense.

# %% [markdown]
# # Carma datasets

# %%
carma_datasets = {}
carma_LCIA= {}

for db_name in database_dict:
    
    carma_datasets[db_name] = [x for x in Database(db_name) if x['name'] in eimod.carma_electricity_ds_name_dict.keys() ]
    lca = LCA({carma_datasets[db_name][0]: 1}, method=lcia_methods['CC'])
    lca.lci()
    lca.lcia()
    lca.score
    carma_LCIA[(database_dict[db_name]['year'], database_dict[db_name]['scenario'])] = LCA_to_df(carma_datasets[db_name], cats = ['CC', 'PMF', 'POF', 'R_Total'])

# %%
for cat in carma_LCIA[(2015, 'BAU')].columns:
    fig, axes=plt.subplots(nrows=1, ncols=len(database_dict.keys()), figsize=(30,6), sharey=True, sharex = True)
    st=plt.suptitle(titles[cat], fontsize='12')
    st.set_y(1.05)
    plt.subplots_adjust(top=1)

    for i, db_name in enumerate(database_dict):
        ax = carma_LCIA[(database_dict[db_name]['year'], database_dict[db_name]['scenario'])][cat].plot.barh(ax = axes[i], title = db_name)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# We need to remember that the carma datasets were made roughly 5 years ago and were modelling power plants in 2025. They likely just expect high improvements in emission control technology. I don't think that we made a mistake when implementing the data.

# %% [markdown]
# # Gas

# %%
gas_cc_datasets = {}
gas_cc_LCIA= {}

for db_name in database_dict:

    gas_cc_datasets[db_name] = [x for x in get_many(Database(db_name), *[*filters.gas_combined_cycle_electricity + eimod.generic_excludes + eimod.no_imports])]
    lca = LCA({gas_cc_datasets[db_name][0]: 1}, method=lcia_methods['CC'])
    lca.lci()
    lca.lcia()
    lca.score
    gas_cc_LCIA[(database_dict[db_name]['year'], database_dict[db_name]['scenario'])] = LCA_to_df(gas_cc_datasets[db_name], cats = ['CC', 'PMF', 'POF', 'R_Total'])

# %%
for cat in gas_cc_LCIA[(2015,'BAU')].columns:
    ax = pd.concat(gas_cc_LCIA)[cat].unstack(level = [0,1]).loc['electricity production, natural gas, combined cycle power plant'].sort_values(by = (2015, 'BAU')).rename(index = location_dict)[db_tuples].plot.bar(figsize = (30,6), title = titles[cat])
    ax.set_ylabel(units[cat] + "/kWh")

# %% [markdown]
# ## Gas open cycle

# %%
gas_oc_datasets = {}
gas_oc_LCIA= {}

for db_name in database_dict:

    gas_oc_datasets[db_name] = [x for x in ws.get_many(Database(db_name), *[*eimod.gas_open_cycle_electricity + eimod.generic_excludes + eimod.no_imports])]
    lca = LCA({gas_oc_datasets[db_name][0]: 1}, method=lcia_methods['CC'])
    lca.lci()
    lca.lcia()
    lca.score
    gas_oc_LCIA[(database_dict[db_name]['year'], database_dict[db_name]['scenario'])] = LCA_to_df(gas_oc_datasets[db_name], cats = ['CC', 'PMF', 'POF', 'R_Total'])

# %%
for cat in gas_oc_LCIA[(2015,'BAU')].columns:
    ax = pd.concat(gas_oc_LCIA)[cat].unstack(level = [0,1]).loc['electricity production, natural gas, conventional power plant'].sort_values(by = (2015, 'BAU')).rename(
        index = location_dict)[db_tuples].plot.bar(figsize = (30,6), title = titles[cat])
    ax.set_ylabel(units[cat] + "/kWh")

# %% [markdown]
# ## Gas CHP

# %%
gas_CHP_datasets = {}
gas_CHP_LCIA= {}

for db_name in database_dict:

    gas_CHP_datasets[db_name] = [x for x in ws.get_many(Database(db_name), *[*filters.gas_chp_electricity + eimod.generic_excludes + eimod.no_imports])]
    lca = LCA({gas_CHP_datasets[db_name][0]: 1}, method=lcia_methods['CC'])
    lca.lci()
    lca.lcia()
    lca.score
    gas_CHP_LCIA[(database_dict[db_name]['year'], database_dict[db_name]['scenario'])] = LCA_to_df(gas_CHP_datasets[db_name], cats = ['CC', 'PMF', 'POF', 'R_Total'])

# %%
for cat in gas_CHP_LCIA[(2015,'BAU')].columns:
    ax = pd.concat(gas_CHP_LCIA)[cat].unstack(level = [0,1])[db_tuples].plot.bar(figsize = (30,6), title = titles[cat])
    ax.set_ylabel(units[cat] + "/kWh")

# %% [markdown]
# # Biomass

# %%
biomass_datasets = {}
biomass_LCIA= {}

for db_name in database_dict:

    biomass_datasets[db_name] = [x for x in ws.get_many(Database(db_name), *[*eimod.biomass_chp_electricity + eimod.generic_excludes + eimod.no_imports])]
    lca = LCA({biomass_datasets[db_name][0]: 1}, method=lcia_methods['CC'])
    lca.lci()
    lca.lcia()
    lca.score
    biomass_LCIA[(database_dict[db_name]['year'], database_dict[db_name]['scenario'])] = LCA_to_df(biomass_datasets[db_name], cats = ['CC', 'PMF', 'POF', 'R_Total'])

# %%
for cat in biomass_LCIA[(2015,'BAU')].columns:
    ax = pd.concat(biomass_LCIA)[cat].unstack(level = [0,1])[db_tuples].plot.bar(figsize = (30,6), title = titles[cat])
    ax.set_ylabel(units[cat] + "/kWh")

# %% [markdown]
# # Oil

# %%
oil_datasets = {}
oil_LCIA= {}

for db_name in database_dict:

    oil_datasets[db_name] = [x for x in ws.get_many(Database(db_name), *[*filters.oil_open_cycle_electricity + eimod.generic_excludes + eimod.no_imports])]
    lca = LCA({oil_datasets[db_name][0]: 1}, method=lcia_methods['CC'])
    lca.lci()
    lca.lcia()
    lca.score
    oil_LCIA[(database_dict[db_name]['year'], database_dict[db_name]['scenario'])] = LCA_to_df(oil_datasets[db_name], cats = ['CC', 'PMF', 'POF', 'R_Total'])

# %%
for cat in oil_LCIA[(2015,'BAU')].columns:
    ax = pd.concat(oil_LCIA)[cat].unstack(level = [0,1])[db_tuples].plot.bar(figsize = (30,6), title = titles[cat])
    ax.set_ylabel(units[cat] + "/kWh")
